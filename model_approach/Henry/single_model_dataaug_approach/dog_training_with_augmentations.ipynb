# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import pickle

# Define the directory where batch files are saved
batch_dir = "batches"

# Load the model base
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
base_model.trainable = False

# Define the model architecture
inputs = tf.keras.Input(shape=(299, 299, 3))
x = inputs
x = tf.keras.applications.inception_v3.preprocess_input(x)
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
outputs = Dense(128, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)
model.summary()

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Iterate through batch files and train the model
num_batches = 42  # Adjust based on the number of batch files
for batch_index in range(num_batches):
    # Load batch data
    X_batch = pickle.load(open(f"{batch_dir}/X_batch_{batch_index}.pickle", "rb"))
    y_batch = pickle.load(open(f"{batch_dir}/y_batch_{batch_index}.pickle", "rb"))

    # Split the data
    x_train_batch, x_test_batch, y_train_batch, y_test_batch = train_test_split(X_batch, y_batch, test_size=0.3, stratify=y_batch)

    # Train the model with the current batch
    model.fit(x_train_batch, y_train_batch, batch_size=16, epochs=10)

# Save the trained model
model.save('128dogs.h5')
# Out:
# WARNING:tensorflow:From c:\Users\suare\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\suare\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\suare\anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 299, 299, 3)       0
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 299, 299, 3)       0
#  da)
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization_94 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
# =================================================================
# Total params: 22361248 (85.30 MB)
# Trainable params: 557952 (2.13 MB)
# Non-trainable params: 21803296 (83.17 MB)
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\suare\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\suare\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 88/88 [==============================] - 70s 720ms/step - loss: 4.1310 - accuracy: 0.1707
# Epoch 2/10
# 88/88 [==============================] - 64s 724ms/step - loss: 2.7999 - accuracy: 0.5429
# Epoch 3/10
# 88/88 [==============================] - 63s 720ms/step - loss: 2.0876 - accuracy: 0.6843
# Epoch 4/10
# 88/88 [==============================] - 63s 721ms/step - loss: 1.5907 - accuracy: 0.7479
# Epoch 5/10
# 88/88 [==============================] - 63s 721ms/step - loss: 1.2968 - accuracy: 0.7850
# Epoch 6/10
# 88/88 [==============================] - 64s 723ms/step - loss: 1.0182 - accuracy: 0.8300
# Epoch 7/10
# 88/88 [==============================] - 64s 723ms/step - loss: 0.8997 - accuracy: 0.8371
# Epoch 8/10
# 88/88 [==============================] - 75s 852ms/step - loss: 0.7398 - accuracy: 0.8700
# Epoch 9/10
# 88/88 [==============================] - 85s 965ms/step - loss: 0.6950 - accuracy: 0.8729
# Epoch 10/10
# 88/88 [==============================] - 84s 950ms/step - loss: 0.6667 - accuracy: 0.8764
# Epoch 1/10
# 88/88 [==============================] - 66s 748ms/step - loss: 1.3563 - accuracy: 0.6814
# Epoch 2/10
# 88/88 [==============================] - 60s 683ms/step - loss: 1.2111 - accuracy: 0.7271
# Epoch 3/10
# 88/88 [==============================] - 58s 662ms/step - loss: 1.0550 - accuracy: 0.7407
# Epoch 4/10
# 88/88 [==============================] - 58s 658ms/step - loss: 0.9002 - accuracy: 0.7914
# Epoch 5/10
# 88/88 [==============================] - 58s 657ms/step - loss: 0.8713 - accuracy: 0.7893
# Epoch 6/10
# 88/88 [==============================] - 58s 662ms/step - loss: 0.8356 - accuracy: 0.8157
# Epoch 7/10
# 88/88 [==============================] - 58s 657ms/step - loss: 0.7969 - accuracy: 0.8064
# Epoch 8/10
# 88/88 [==============================] - 58s 660ms/step - loss: 0.7938 - accuracy: 0.8093
# Epoch 9/10
# 88/88 [==============================] - 58s 659ms/step - loss: 0.7913 - accuracy: 0.7993
# Epoch 10/10
# 88/88 [==============================] - 58s 661ms/step - loss: 0.7832 - accuracy: 0.8179
# Epoch 1/10
# 88/88 [==============================] - 60s 678ms/step - loss: 1.3567 - accuracy: 0.6529
# Epoch 2/10
# 88/88 [==============================] - 58s 661ms/step - loss: 1.1705 - accuracy: 0.6879
# Epoch 3/10
# 88/88 [==============================] - 59s 670ms/step - loss: 1.1030 - accuracy: 0.7236
# Epoch 4/10
# 88/88 [==============================] - 58s 656ms/step - loss: 1.0987 - accuracy: 0.7200
# Epoch 5/10
# 88/88 [==============================] - 58s 659ms/step - loss: 1.1432 - accuracy: 0.7050
# Epoch 6/10
# 88/88 [==============================] - 58s 657ms/step - loss: 1.0818 - accuracy: 0.7243
# Epoch 7/10
# 88/88 [==============================] - 58s 656ms/step - loss: 1.0810 - accuracy: 0.7157
# Epoch 8/10
# 88/88 [==============================] - 58s 656ms/step - loss: 1.0438 - accuracy: 0.7257
# Epoch 9/10
# 88/88 [==============================] - 58s 656ms/step - loss: 0.9718 - accuracy: 0.7543
# Epoch 10/10
# 88/88 [==============================] - 58s 659ms/step - loss: 0.8903 - accuracy: 0.7700
# Epoch 1/10
# 88/88 [==============================] - 58s 659ms/step - loss: 1.3776 - accuracy: 0.6414
# Epoch 2/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.1951 - accuracy: 0.6800
# Epoch 3/10
# 88/88 [==============================] - 58s 656ms/step - loss: 1.1000 - accuracy: 0.6964
# Epoch 4/10
# 88/88 [==============================] - 58s 659ms/step - loss: 1.0887 - accuracy: 0.7071
# Epoch 5/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.1054 - accuracy: 0.7043
# Epoch 6/10
# 88/88 [==============================] - 58s 658ms/step - loss: 1.1409 - accuracy: 0.6929
# Epoch 7/10
# 88/88 [==============================] - 58s 657ms/step - loss: 1.1606 - accuracy: 0.6871
# Epoch 8/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.1146 - accuracy: 0.7029
# Epoch 9/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.1091 - accuracy: 0.7114
# Epoch 10/10
# 88/88 [==============================] - 58s 654ms/step - loss: 1.1271 - accuracy: 0.6914
# Epoch 1/10
# 88/88 [==============================] - 58s 665ms/step - loss: 1.4622 - accuracy: 0.6150
# Epoch 2/10
# 88/88 [==============================] - 58s 663ms/step - loss: 1.3717 - accuracy: 0.6443
# Epoch 3/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.3523 - accuracy: 0.6343
# Epoch 4/10
# 88/88 [==============================] - 58s 659ms/step - loss: 1.2752 - accuracy: 0.6564
# Epoch 5/10
# 88/88 [==============================] - 58s 657ms/step - loss: 1.1313 - accuracy: 0.6836
# Epoch 6/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.1628 - accuracy: 0.6814
# Epoch 7/10
# 88/88 [==============================] - 58s 656ms/step - loss: 1.1461 - accuracy: 0.6821
# Epoch 8/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.1049 - accuracy: 0.7007
# Epoch 9/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.1175 - accuracy: 0.6971
# Epoch 10/10
# 88/88 [==============================] - 58s 657ms/step - loss: 1.0960 - accuracy: 0.7029
# Epoch 1/10
# 88/88 [==============================] - 58s 658ms/step - loss: 1.5932 - accuracy: 0.5807
# Epoch 2/10
# 88/88 [==============================] - 58s 657ms/step - loss: 1.5402 - accuracy: 0.5900
# Epoch 3/10
# 88/88 [==============================] - 58s 656ms/step - loss: 1.5076 - accuracy: 0.5929
# Epoch 4/10
# 88/88 [==============================] - 58s 657ms/step - loss: 1.4879 - accuracy: 0.5957
# Epoch 5/10
# 88/88 [==============================] - 58s 654ms/step - loss: 1.4904 - accuracy: 0.5943
# Epoch 6/10
# 88/88 [==============================] - 57s 652ms/step - loss: 1.4366 - accuracy: 0.5979
# Epoch 7/10
# 88/88 [==============================] - 57s 650ms/step - loss: 1.4079 - accuracy: 0.6179
# Epoch 8/10
# 88/88 [==============================] - 57s 653ms/step - loss: 1.3564 - accuracy: 0.6114
# Epoch 9/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.2938 - accuracy: 0.6421
# Epoch 10/10
# 88/88 [==============================] - 58s 661ms/step - loss: 1.3493 - accuracy: 0.6200
# Epoch 1/10
# 88/88 [==============================] - 59s 669ms/step - loss: 1.8112 - accuracy: 0.5271
# Epoch 2/10
# 88/88 [==============================] - 58s 659ms/step - loss: 1.7773 - accuracy: 0.5321
# Epoch 3/10
# 88/88 [==============================] - 58s 655ms/step - loss: 1.7534 - accuracy: 0.5243
# Epoch 4/10
# 88/88 [==============================] - 58s 656ms/step - loss: 1.6981 - accuracy: 0.5414
# Epoch 5/10
# 88/88 [==============================] - 58s 659ms/step - loss: 1.6947 - accuracy: 0.5586
# Epoch 6/10
# 88/88 [==============================] - 58s 663ms/step - loss: 1.6051 - accuracy: 0.5793
# Epoch 7/10
# 88/88 [==============================] - 58s 657ms/step - loss: 1.5705 - accuracy: 0.5721
# Epoch 8/10
# 88/88 [==============================] - 58s 656ms/step - loss: 1.5609 - accuracy: 0.5679
# Epoch 9/10
# 88/88 [==============================] - 58s 660ms/step - loss: 1.6212 - accuracy: 0.5700
# Epoch 10/10
# 88/88 [==============================] - 59s 666ms/step - loss: 1.5759 - accuracy: 0.5779
# Epoch 1/10
# 88/88 [==============================] - 65s 739ms/step - loss: 1.9500 - accuracy: 0.4836
# Epoch 2/10
# 88/88 [==============================] - 70s 801ms/step - loss: 1.9130 - accuracy: 0.4907
# Epoch 3/10
# 88/88 [==============================] - 64s 730ms/step - loss: 1.8294 - accuracy: 0.5064
# Epoch 4/10
# 88/88 [==============================] - 78s 884ms/step - loss: 1.8303 - accuracy: 0.5036
# Epoch 5/10
# 88/88 [==============================] - 65s 742ms/step - loss: 1.7159 - accuracy: 0.5307
# Epoch 6/10
# 88/88 [==============================] - 58s 662ms/step - loss: 1.7817 - accuracy: 0.5164
# Epoch 7/10
# 88/88 [==============================] - 58s 658ms/step - loss: 1.7332 - accuracy: 0.5193
# Epoch 8/10
# 88/88 [==============================] - 58s 658ms/step - loss: 1.7944 - accuracy: 0.5193
# Epoch 9/10
# 88/88 [==============================] - 58s 659ms/step - loss: 1.8028 - accuracy: 0.5179
# Epoch 10/10
# 88/88 [==============================] - 58s 664ms/step - loss: 2.0770 - accuracy: 0.4364
# Epoch 1/10
# 88/88 [==============================] - 62s 703ms/step - loss: 2.2748 - accuracy: 0.3836
# Epoch 2/10
# 88/88 [==============================] - 60s 687ms/step - loss: 2.1369 - accuracy: 0.4264
# Epoch 3/10
# 88/88 [==============================] - 58s 664ms/step - loss: 2.0935 - accuracy: 0.4550
# Epoch 4/10
# 88/88 [==============================] - 58s 660ms/step - loss: 2.1425 - accuracy: 0.4250
# Epoch 5/10
# 88/88 [==============================] - 58s 661ms/step - loss: 2.1335 - accuracy: 0.4300
# Epoch 6/10
# 88/88 [==============================] - 59s 668ms/step - loss: 2.0606 - accuracy: 0.4500
# Epoch 7/10
# 88/88 [==============================] - 59s 676ms/step - loss: 2.1641 - accuracy: 0.4300
# Epoch 8/10
# 88/88 [==============================] - 58s 661ms/step - loss: 2.2182 - accuracy: 0.4064
# Epoch 9/10
# 88/88 [==============================] - 58s 660ms/step - loss: 2.1312 - accuracy: 0.4293
# Epoch 10/10
# 88/88 [==============================] - 59s 669ms/step - loss: 2.2273 - accuracy: 0.4079
# Epoch 1/10
# 88/88 [==============================] - 59s 671ms/step - loss: 2.3611 - accuracy: 0.3714
# Epoch 2/10
# 88/88 [==============================] - 59s 667ms/step - loss: 2.1555 - accuracy: 0.4229
# Epoch 3/10
# 88/88 [==============================] - 58s 661ms/step - loss: 1.9750 - accuracy: 0.4550
# Epoch 4/10
# 88/88 [==============================] - 58s 658ms/step - loss: 2.1036 - accuracy: 0.4400
# Epoch 5/10
# 88/88 [==============================] - 59s 674ms/step - loss: 2.0597 - accuracy: 0.4314
# Epoch 6/10
# 88/88 [==============================] - 58s 661ms/step - loss: 1.9778 - accuracy: 0.4500
# Epoch 7/10
# 88/88 [==============================] - 57s 645ms/step - loss: 1.8239 - accuracy: 0.5157
# Epoch 8/10
# 88/88 [==============================] - 57s 643ms/step - loss: 1.9239 - accuracy: 0.4643
# Epoch 9/10
# 88/88 [==============================] - 57s 643ms/step - loss: 1.9149 - accuracy: 0.4821
# Epoch 10/10
# 88/88 [==============================] - 57s 647ms/step - loss: 1.9076 - accuracy: 0.4700
# Epoch 1/10
# 88/88 [==============================] - 57s 649ms/step - loss: 2.1943 - accuracy: 0.4321
# Epoch 2/10
# 88/88 [==============================] - 57s 644ms/step - loss: 2.1722 - accuracy: 0.4421
# Epoch 3/10
# 88/88 [==============================] - 57s 643ms/step - loss: 1.9831 - accuracy: 0.4679
# Epoch 4/10
# 88/88 [==============================] - 57s 648ms/step - loss: 2.0765 - accuracy: 0.4450
# Epoch 5/10
# 88/88 [==============================] - 57s 646ms/step - loss: 1.9107 - accuracy: 0.4821
# Epoch 6/10
# 88/88 [==============================] - 57s 644ms/step - loss: 1.8017 - accuracy: 0.5171
# Epoch 7/10
# 88/88 [==============================] - 57s 643ms/step - loss: 1.8475 - accuracy: 0.5057
# Epoch 8/10
# 88/88 [==============================] - 57s 643ms/step - loss: 1.8306 - accuracy: 0.5186
# Epoch 9/10
# 88/88 [==============================] - 57s 643ms/step - loss: 1.7496 - accuracy: 0.5321
# Epoch 10/10
# 88/88 [==============================] - 57s 643ms/step - loss: 1.7732 - accuracy: 0.5136
# Epoch 1/10
# 88/88 [==============================] - 60s 682ms/step - loss: 2.1073 - accuracy: 0.4407
# Epoch 2/10
# 88/88 [==============================] - 68s 771ms/step - loss: 2.0024 - accuracy: 0.4736
# Epoch 3/10
# 88/88 [==============================] - 62s 706ms/step - loss: 1.9572 - accuracy: 0.4657
# Epoch 4/10
# 88/88 [==============================] - 70s 795ms/step - loss: 1.8351 - accuracy: 0.5007
# Epoch 5/10
# 88/88 [==============================] - 63s 714ms/step - loss: 1.7195 - accuracy: 0.5057
# Epoch 6/10
# 88/88 [==============================] - 62s 703ms/step - loss: 1.7002 - accuracy: 0.5257
# Epoch 7/10
# 88/88 [==============================] - 61s 697ms/step - loss: 1.6964 - accuracy: 0.5236
# Epoch 8/10
# 88/88 [==============================] - 62s 710ms/step - loss: 1.7649 - accuracy: 0.5279
# Epoch 9/10
# 88/88 [==============================] - 68s 771ms/step - loss: 1.8893 - accuracy: 0.4814
# Epoch 10/10
# 88/88 [==============================] - 68s 770ms/step - loss: 1.9119 - accuracy: 0.4664
# Epoch 1/10
# 88/88 [==============================] - 69s 779ms/step - loss: 2.3761 - accuracy: 0.3750
# Epoch 2/10
# 88/88 [==============================] - 69s 786ms/step - loss: 2.2033 - accuracy: 0.4286
# Epoch 3/10
# 88/88 [==============================] - 67s 763ms/step - loss: 2.1192 - accuracy: 0.4350
# Epoch 4/10
# 88/88 [==============================] - 72s 818ms/step - loss: 1.9830 - accuracy: 0.4457
# Epoch 5/10
# 44/88 [==============>...............] - ETA: 36s - loss: 2.0535 - accuracy: 0.4219
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 44
#      41     x_train_batch, x_test_batch, y_train_batch, y_test_batch = train_test_split(X_batch, y_batch, test_size=0.3, stratify=y_batch)
#      43     # Train the model with the current batch
# ---> 44     model.fit(x_train_batch, y_train_batch, batch_size=16, epochs=10)
#      46 # Save the trained model
#      47 model.save('128dogs.h5')
#
# File c:\Users\suare\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\suare\anaconda3\Lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File c:\Users\suare\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
